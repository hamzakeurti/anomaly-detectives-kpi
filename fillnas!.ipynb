# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from extraction import Seasonality,Time
import Util
from visualization import visualize

# %%
df = Util.load_train()

# %%
KPIs = Time.split_on_id(df)
KPI_ids = list(KPIs.keys())

# %%
single_KPI = KPIs[KPI_ids[0]].copy()
single_KPI_copy = single_KPI.copy()

# %%
single_KPI_copy.loc[single_KPI.label == 1,"value"] = np.nan

# %%
Time.format_timestamp(single_KPI_copy)
single_KPI_copy = Time.fill_nas(single_KPI_copy,ignore_anomaly=False)

# %%
Time.format_timestamp(single_KPI)
single_KPI = Time.fill_nas(single_KPI,ignore_anomaly=False)

# %%
diff = single_KPI[single_KPI.imputed==0].value - single_KPI_copy[single_KPI.imputed==0].value

# %%
diff
# Out:
# 2017-05-01 00:00:00    0.0
# 2017-05-01 00:01:00    0.0
# 2017-05-01 00:02:00    0.0
# 2017-05-01 00:03:00    0.0
# 2017-05-01 00:04:00    0.0
# 2017-05-01 00:05:00    0.0
# 2017-05-01 00:06:00    0.0
# 2017-05-01 00:07:00    0.0
# 2017-05-01 00:08:00    0.0
# 2017-05-01 00:09:00    0.0
# 2017-05-01 00:10:00    0.0
# 2017-05-01 00:11:00    0.0
# 2017-05-01 00:12:00    0.0
# 2017-05-01 00:13:00    0.0
# 2017-05-01 00:14:00    0.0
# 2017-05-01 00:15:00    0.0
# 2017-05-01 00:16:00    0.0
# 2017-05-01 00:17:00    0.0
# 2017-05-01 00:18:00    0.0
# 2017-05-01 00:19:00    0.0
# 2017-05-01 00:20:00    0.0
# 2017-05-01 00:21:00    0.0
# 2017-05-01 00:22:00    0.0
# 2017-05-01 00:23:00    0.0
# 2017-05-01 00:24:00    0.0
# 2017-05-01 00:25:00    0.0
# 2017-05-01 00:26:00    0.0
# 2017-05-01 00:27:00    0.0
# 2017-05-01 00:28:00    0.0
# 2017-05-01 00:29:00    0.0
#                       ...
# 2017-07-31 12:05:00    0.0
# 2017-07-31 12:06:00    0.0
# 2017-07-31 12:07:00    0.0
# ...

# %%
fig = visualize.visualize_anomalies(diff.index,diff.values,single_KPI[single_KPI.imputed == 0].label.values)
# Out:
# <img src="data:image/png;base64,..." width="1000">
